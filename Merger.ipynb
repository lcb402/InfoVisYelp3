# %%
import csv
import pandas as pd
business_file ='yelp_academic_dataset_business.csv'
tips_file ='yelp_academic_dataset_tip.csv'
reviews_file = 'yelp_academic_dataset_review.csv'
tips_fields = ['business_id','user_id','date']
business_fields = ['attributes_Price Range','name','business_id', 
                   'categories','review_count', 'stars', 'state']

business_dataframe = pd.read_csv(business_file, low_memory=False, usecols= business_fields)

tips_dataframe = pd.read_csv(tips_file, low_memory= False, usecols = tips_fields)

business_dataframe = pd.read_csv(business_file, low_memory=False, usecols= business_fields)

tips_dataframe = pd.read_csv(tips_file, low_memory= False, usecols = tips_fields)

# %%
business_dataframe.head()
# Out:
#    attributes_Price Range             business_id  \
# 0                       1  5UmKMjUEUNdYWqANhGckJw
# 1                       1  UsFtqoBl7naz8AVUBZMjQQ
# 2                     NaN  cE27W9VPgO88Qxe4ol6y_g
# 3                       2  mVHrayjG3uZ_RLHkLj-AMg
# 4                     NaN  mYSpR_SLPgUVymYOvTQd_Q
#
#                                           categories  \
# 0                              Fast Food,Restaurants
# 1                                          Nightlife
# 2                         Active Life,Mini Golf,Golf
# 3  Bars,American (New),Nightlife,Lounges,Restaurants
# 4                                   Active Life,Golf
#
#                        name  review_count  stars state
# 0                 Mr Hoagie             7    3.5    PA
# 1              Clancy's Pub             5    3.0    PA
# 2  Cool Springs Golf Center             5    2.5    PA
# 3             Emil's Lounge            26    4.5    PA
# 4      Grand View Golf Club             3    5.0    PA

# %%
tips_dataframe.head()
# Out:
#               business_id        date                 user_id year_tips  \
# 0  5UmKMjUEUNdYWqANhGckJw  2016-07-17  ZxdojCZgZhw36xuSGaryRg      2016
# 1  cE27W9VPgO88Qxe4ol6y_g  2013-04-18  -6rEfobYjMxpUWLNxszaxQ      2013
# 2  mVHrayjG3uZ_RLHkLj-AMg  2016-02-22  5OumCBQ_MyQsltSdbMyunA      2016
# 3  mVHrayjG3uZ_RLHkLj-AMg  2013-01-06  EZ0r9dKKtEGVx2CdnowPCw      2013
# 4  KayYbHCt-RkbGcPdGOThNg  2013-12-03  xb6zEQCw9I-Gl0g06e1KsQ      2013
#
#   month_tips
# 0         07
# 1         04
# 2         02
# 3         01
# 4         12

# %%
tip_dates  = tips_dataframe['date'].tolist()

# %%
tip_dates[1:10]
# Out:
# ['2013-04-18',
#  '2016-02-22',
#  '2013-01-06',
#  '2013-12-03',
#  '2015-07-08',
#  '2016-02-18',
#  '2016-05-05',
#  '2015-10-25',
#  '2015-01-06']

# %%
year = []
month = []
for i in tips_dataframe.index:
    y, m, d =tip_dates[i].split('-')
    year.append(y)
    month.append(m)

# %%
tips_dataframe["tip_year"] = year

# %%
tips_dataframe['tip_month'] = month

# %%
tips_dataframe.head()
# Out:
#               business_id        date                 user_id year_tips  \
# 0  5UmKMjUEUNdYWqANhGckJw  2016-07-17  ZxdojCZgZhw36xuSGaryRg      2016
# 1  cE27W9VPgO88Qxe4ol6y_g  2013-04-18  -6rEfobYjMxpUWLNxszaxQ      2013
# 2  mVHrayjG3uZ_RLHkLj-AMg  2016-02-22  5OumCBQ_MyQsltSdbMyunA      2016
# 3  mVHrayjG3uZ_RLHkLj-AMg  2013-01-06  EZ0r9dKKtEGVx2CdnowPCw      2013
# 4  KayYbHCt-RkbGcPdGOThNg  2013-12-03  xb6zEQCw9I-Gl0g06e1KsQ      2013
#
#   month_tips
# 0         07
# 1         04
# 2         02
# 3         01
# 4         12

# %%
tips_dataframe.rename(columns={'tip_year': 'year_tips', 'tip_month': 'month_tips'}, inplace=True)

# %%
review_fields = ['business_id', 'user_id','date']
reviews_dataframe = pd.read_csv(reviews_file, skipinitialspace = True, usecols = review_fields)

# %%
reviews_dataframe.head()
# Out:
#               business_id       date                 user_id
# 0  5UmKMjUEUNdYWqANhGckJw 2012-08-01  PUFPaY9KxDAcGqfsorJp3Q
# 1  5UmKMjUEUNdYWqANhGckJw 2014-02-13  Iu6AxdBYGR4A0wspR9BYHA
# 2  5UmKMjUEUNdYWqANhGckJw 2015-10-31  auESFwWvW42h6alXgFxAXQ
# 3  5UmKMjUEUNdYWqANhGckJw 2015-12-26  qiczib2fO_1VBG8IoCGvVg
# 4  5UmKMjUEUNdYWqANhGckJw 2016-04-08  qEE5EvV-f-s7yHC0Z4ydJQ

# %%
reviews_dataframe['date'] = pd.to_datetime(reviews_dataframe['date'],errors = 'ignore', 
                                           infer_datetime_format=True)

# %%
reviews_dataframe['date'].value_counts()
# Out:
# 2016-04-02    2667
# 2016-02-15    2623
# 2016-07-16    2595
# 2016-06-25    2582
# 2016-02-14    2572
# 2016-07-09    2540
# 2016-07-15    2536
# 2016-04-09    2523
# 2016-02-20    2516
# 2016-02-13    2509
# 2016-04-16    2507
# 2016-06-04    2503
# 2016-04-03    2501
# 2016-03-26    2496
# 2016-06-29    2496
# 2016-03-19    2483
# 2016-05-15    2472
# 2016-05-21    2455
# 2016-06-24    2451
# 2016-07-17    2449
# 2016-04-30    2448
# 2016-07-10    2430
# 2016-07-02    2428
# 2016-02-27    2419
# 2016-07-06    2417
# 2016-06-11    2406
# 2016-03-12    2405
# 2016-03-05    2403
# 2016-01-16    2403
# 2016-05-29    2392
#               ...
# 2005-10-02       1
# 2005-04-13       1
# 2005-08-20       1
# 2006-07-01       1
# 2005-07-05       1
# 2004-10-24       1
# 2004-12-24       1
# 2005-07-13       1
# 2005-04-18       1
# 2006-06-02       1
# 2005-12-25       1
# 2005-08-29       1
# 2005-12-17       1
# 2005-01-26       1
# 2005-03-29       1
# 2005-03-04       1
# ...

# %%
reviews_dataframe.sort_values('date',ascending = False)
# Out:
#                                                business_id       date  \
# 1620328                             v7TjQ1_RPEF26vy8rc41Lg 2016-07-19
# 2044128                             HhSB3tq8CCFpB0ZQ7IXSoQ 2016-07-19
# 1379822                             _WvbrTZwNIftx_eh2WMoPQ 2016-07-19
# 2099928                             iyRIug4cmEeOle9k7XU2oA 2016-07-19
# 2467537                             L7e69D5CCLfT85NWg5X1Ow 2016-07-19
# 2633770                             c8b7niizd3jigDlq-z_E6Q 2016-07-19
# 1141244                             3StNFdnfDPYWYsMZyvGFpA 2016-07-19
# 848642                              ilAHA82RvrT2p04qYh1LWw 2016-07-19
# 1380820                             ZqbLzCYPdDNL97lwoiQmWQ 2016-07-19
# 848832                              ZUT4--fvhGpQISIS3NN-Gw 2016-07-19
# 1140959                             ieUk5bgTIzIZiZ1fIapntw 2016-07-19
# 1379795                             pRIBc4emwv9QCTPuS2aZDA 2016-07-19
# ...

# %%
review_dates = reviews_dataframe['date'].tolist()
r_year = []
r_month = []
for i in reviews_dataframe.index:
    y, m,d = review_dates[i].split('-')
    r_year.append(y)
    r_month.append(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-7fd1c17b2607> in <module>()
#       3 r_month = []
#       4 for i in reviews_dataframe.index:
# ----> 5     y, m,d = review_dates[i].split('-')
#       6     r_year.append(y)
#       7     r_month.append(m)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
reviews_dataframe['date'][0].split('-')
# Out:
# ['2012', '08', '01']

# %%
reviews_dataframe['date'] = [d.strftime('%Y-%m-%d') 
                             if not pd.isnull(d) else '' for d in reviews_dataframe['date']]

# %%
review_dates[0].strftime('%Y/%M/%D/%H')
y =t.split('/')[0]
m = t.split('/')[2]

# %%
reviews_dataframe = Series.str.startwith('20')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-481ff4b33f6c> in <module>()
# ----> 1 reviews_dataframe = reviews_dataframe[reviews_dataframe.date != np.nat]
#
# AttributeError: module 'numpy' has no attribute 'nat'

# %%
reviews_dataframe.sort_values('date',ascending = False).tail()
# Out:
#                                                business_id        date  \
# 540150                              leH24AjTrmcImAbsdh4HFQ  2004-10-19
# 570050                              -7yF42k0CcJhtPw51oaOqQ  2004-10-18
# 540133                              laMD1HamiWT7pKRXDwjasA  2004-10-12
# 539855                              zMN8UGd1zDEreT58OCdnyg  2004-10-12
# 1412534  All the goodness of the deep South! Seasoned a...
#
#                         user_id
# 540150   rpOyqD_893cqmDAtJLbdog
# 570050   rpOyqD_893cqmDAtJLbdog
# 540133   fHtTaujcyKvXglE33Z5yIw
# 539855   fHtTaujcyKvXglE33Z5yIw
# 1412534                     NaN
